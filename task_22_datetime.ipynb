# %%
from datetime import datetime

# %%
now=datetime.now()
print(f"current date and time is:{now}")
# Out:
# current date and time is:2026-07-08 12:20:13.393726

# %%
from datetime import datetime,timedelta
now=datetime.now()
print(now)
print(now.strftime("%D-%m-%y"))
print(now.strftime("%H-%m-%S"))
# Out:
# 2026-07-08 12:33:15.810174
# 07/08/26-07-26
# 12-07-15

# %%
from datetime import datetime

# %%
birth_year=int(input("Enter you birth year:"))
current_year=datetime.now().year
age=current_year-birth_year
print("your age is:",age)
# Out:
# your age is: 23

# %%
#4. Countdown to Event (timedelta)


today = datetime.now()
event=datetime(2026,12,21)
days=event-today
print(days)

# %%
today=datetime.now()
event=datetime(2026,7,11)
days=event-today
print(days)
# Out:
# 2 days, 11:12:59.895047

# %%
d1=datetime(2026,2,11)
d2=datetime(2026,4,11)
diff=d2-d1
print(diff)
# Out:
# 59 days, 0:00:00

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 #6. Add Days Using timedelta
# ----> 4 today=datetime.now()
#       5 future=today +timedelta(days=15)
#       7 print("TODAY",today.strftime("%D-%M-%Y"))
#
# NameError: name 'datetime' is not defined
